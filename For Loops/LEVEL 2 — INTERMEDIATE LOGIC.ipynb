# %% [markdown]
# ## 🟡 LEVEL 2 — INTERMEDIATE LOGIC
# - Combininge math functions with logical conditions and nested loops.

# %% [markdown]
#  1. 	Given a list of numbers, print only those divisible by both 3 and 5.

# %% [markdown]
# 12.	Given two lists, find all numbers that appear in both.

# %%
#numbers = [45, 78, 89, 56, 92, 67, 74, 88, 53, 99]

numbers = [1,2,3,4,5]

for x in numbers:
    if x % 5 == 0 and x % 3 == 0:
        print (f"The number {x} is divisible by both 5 and 3")

# %%
numbers_list1=[5, 10, 35, -20, 25,15]
numbers_list2=[5, 10, 45, -20, 20,15]
common = []
for num in numbers_list1:
    for items in numbers_list2:
        if num == items:
            common.append(num)
print(f"The elments common between the two lists are {common}")
# Out:
# The elments common between the two lists are [5, 10, -20, 15]

# %% [markdown]
# 13.	Count how many even and odd numbers are in a list.

# %%
odd_count=0
even_count=0
for num in numbers:
    if num%2 == 0:
        odd_count = odd_count+1
    elif num%2 != 0:
        even_count = even_count+1

print(f"Odd Count : {odd_count}")
print(f"Even Count : {even_count}")
# Out:
# Odd Count : 5
# Even Count : 5

# %% [markdown]
# 14.	Check if a list is sorted in ascending order.

# %%
max_number = numbers[0]
counter = 0
for nums in numbers:
    if nums > max_number:
      counter = counter + 1
if counter != 0:
    print(f" The provided list is not in ascending order")
# Out:
#  The provided list is not in ascending order

# %% [markdown]
# 15.	Find the difference between the largest and smallest numbers in a list.

# %%
max_number = numbers[0]
min_number = numbers[0]
for number in numbers:
    if number < min_number:
        min_number = number
    if number > max_number:
        max_number = number
print(f" Min number : {min_number}")
print(f" Max Number : {max_number}")
print(f" Difference between the minimum and maximum no is : {max_number - min_number}")
# Out:
#  Min number : 45
#  Max Number : 99
#  Difference between the minimum and maximum no is : 54

# %% [markdown]
# 16.	Compute the sum of only even numbers in a list.

# %%
total_even = 0
for number in numbers:
    if number % 2 == 0:
        total_even = total_even + number 
print(f" The sum of the even numbers are : {total_even}")
# Out:
#  The sum of the even numbers are : 388

# %% [markdown]
# 17.	Calculate the running total (cumulative sum) of a list.

# %%
total = 0
for number in numbers:
    total = total + number
print(f" The sum of the list is {total}")
# Out:
#  The sum of the list is 741

# %% [markdown]
# 18.	Given a list of test scores, count how many are above the class average.

# %%
test_scores = [45, 78, 89, 56, 92, 67, 74, 88, 53, 99]
counter = 0
sum = 0
above_average_count = 0
for score in test_scores:
    sum = sum + score
    counter = counter + 1 
average = sum / counter
for scores in test_scores:
    if scores > average:
        above_average_count = above_average_count + 1
print(f" The  average score of the class is : {average}")
print(f" The total no of students in the class are : {counter}")
print(f" The total no of students above average are : {above_average_count}")
# Out:
#  The  average score of the class is : 74.1
#  The total no of students in the class are : 10
#  The total no of students above average are : 5

# %% [markdown]
# 19.	Write a loop to find the second-largest number in a list.

# %%
flargest = numbers[0]
slargest = numbers[0]
for fnumber in numbers:
    if number > flargest:
        flargest = number
for snumber in numbers:
    if number > slargest and number < flargest:
        slargest = number
print (f"The first largest number is {flargest}")
print (f" The second largest number is {slargest}")
# Out:
# The first largest number is 99
#  The second largest number is 45

# %% [markdown]
# 20.	Find all pairs of numbers in a list whose sum is equal to 10.

# %%
flag = 0
for key1 in range(key1,len(numbers)):
    for key2  in numbers:
        if key1 + key2 == 10:
            if key1 != key2:
                print(f" The pairs that make the sum of 10 is {key1} and {key2}")
                flag = flag + 1
if flag == 0:
    print(f" There are no pairs in the given list whose sum is equal to 10")
# Out:
#  There are no pairs in the given list whose sum is equal to 10
